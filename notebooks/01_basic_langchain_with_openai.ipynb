# %% [markdown]
# #### Load Environment Variables

# %%
from dotenv import load_dotenv
import os
load_dotenv(override=True)
# Out:
# Key exists: True
# Key prefix: sk-or-v1-0

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(
    model="openai/gpt-oss-20b:free",
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1"
)

# %%
res = llm.invoke("who is pm of India?")
print(res.content)
# Out:
# The current Prime Minister of India is **Narendra Modi**. He has been in office since May 26, 2014, leading the Bharatiya Janata Party (BJP) and serving as the head of the Indian government.

# %% [markdown]
# #### How to Write Prompts

# %%
prompts = [
    ("system", "you are a python developer"), # "system", "ai", "user"
    ("user", "write a python function to add two numbers"),
]

res = llm.invoke(prompts)
print(res.content)
# Out:
# Here’s a minimal, well‑documented Python function that adds two numbers:
#
# ```python
# def add(a: float | int, b: float | int) -> float:
#     """
#     Return the sum of two numbers.
#
#     Parameters
#     ----------
#     a : int | float
#         First operand.
#     b : int | float
#         Second operand.
#
#     Returns
#     -------
#     float
#         The result of a + b.  If both arguments are integers the result
#         will be an integer; otherwise it will be a float.
#
#     Examples
#     --------
#     >>> add(3, 5)
#     8
#     >>> add(2.5, 4)
#     6.5
#     """
#     return a + b
# ```
#
# ### How to use it
#
# ```python
# print(add(10, 15))   # 25
# print(add(1.2, 3.4)) # 4.6
# ```
#
# Feel free to adjust the type hints or return type if you need stricter type enforcement.
