# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langgraph.checkpoint.memory import MemorySaver
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_9692\3293250410.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import GoogleSerperAPIWrapper

# %%
llm = ChatGroq(model="llama-3.3-70b-versatile")
search = GoogleSerperAPIWrapper()

# %%
agent = create_agent(
    model = llm,
    tools = [search.run],
    system_prompt="You are a agent and can search for any question on google.",
    checkpointer=MemorySaver()
)

# %%
question = "What is the chances of conversion from intern to full-time employee ?"

# %%
res = agent.invoke(
    {"messages":[{"role":"user", "content":question}]},
    {"configurable": {"thread_id": "asd123"}},
)

# %%
print(res["messages"][-1].content)
# Out:
# The conversion rate from intern to full-time employee at Trianz is not explicitly stated in the search results. However, according to the National Association of Colleges and Employers, the average intern-to-hire conversion rate is around 63.1%. It's also mentioned that the conversion rate can vary depending on the company and industry. To get a more accurate answer, I would suggest checking with Trianz directly or looking for more specific information on their internship program.
